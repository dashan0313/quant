# %%
import pywt
import numpy as np
import pandas as pd
from sklearn import svm,preprocessing
import tushare as ts
import matplotlib.pyplot as plt
#正常显示画图时出现的中文和负号
from pylab import mpl
#mpl.rcParams['font.sans-serif']=['SimHei']
#mpl.rcParams['axes.unicode_minus']=False

import re

token = 'c5cba6dd1dc9c4c3578cdd046f54dfc4119fef2aabf7f998ed9a5192'
ts.set_token(token)
pro = ts.pro_api(token)

# %%
pa = pd.read_csv('../data/DAT_XLSX_USDHKD_M1_202010.csv')
pa.head()
# Out:
#      DateTime Stamp  Bar OPEN Bid Quote  Bar HIGH Bid Quote  \
# 0  2020-10-01 00:00             7.74991             7.74994
# 1  2020-10-01 00:01             7.74997             7.74997
# 2  2020-10-01 00:02             7.74993             7.75001
# 3  2020-10-01 00:03             7.74997             7.75001
# 4  2020-10-01 00:04             7.74991             7.75002
#
#    Bar LOW Bid Quote  Bar CLOSE Bid Quote  Volume
# 0            7.74991              7.74994     0.0
# 1            7.74997              7.74997     0.0
# 2            7.74993              7.75001     0.0
# 3            7.74997              7.75001     0.0
# 4            7.74991              7.75002     0.0

# %%
def get_month(dt):
    return re.findall('2020-10-(.+) ',dt)[0]

# %%
pa['day'] = pa['DateTime Stamp'].apply(get_month)
r = np.log(pa.iloc[1:pa.shape[0],4].values/pa.iloc[0:pa.shape[0]-1,4].values)
pa['return'] = [0]+list(r)
pa.head()
# Out:
#      DateTime Stamp  Bar OPEN Bid Quote  Bar HIGH Bid Quote  \
# 0  2020-10-01 00:00             7.74991             7.74994
# 1  2020-10-01 00:01             7.74997             7.74997
# 2  2020-10-01 00:02             7.74993             7.75001
# 3  2020-10-01 00:03             7.74997             7.75001
# 4  2020-10-01 00:04             7.74991             7.75002
#
#    Bar LOW Bid Quote  Bar CLOSE Bid Quote  Volume day    return
# 0            7.74991              7.74994     0.0  01  0.000000
# 1            7.74997              7.74997     0.0  01  0.000004
# 2            7.74993              7.75001     0.0  01  0.000005
# 3            7.74997              7.75001     0.0  01  0.000000
# 4            7.74991              7.75002     0.0  01  0.000001

# %%
pa.columns=['datetime','open','high','low','close','volumn','day','return']

# %%
pa = pa[pa.day=='01'][:700]

# %%
plt.plot(pa['return'])

# %%
plt.plot(pa.close)

# %% [markdown]
# 小波分析：
# 1. Decomposition --将信号分解成N层小波
# 2. Denoise --对于分解的小波，选择阈值进行去噪声处理
# 3. Reconstruction --将去噪以后的小波（高频）和未处理的小波（低频）重构得到信号

# %%
print('查看小波函数族：',pywt.families())
print('查看sym小波族下的所有函数：',pywt.wavelist(family='sym',kind='all'))
# Out:
# 查看小波函数族： ['haar', 'db', 'sym', 'coif', 'bior', 'rbio', 'dmey', 'gaus', 'mexh', 'morl', 'cgau', 'shan', 'fbsp', 'cmor']
# 查看sym小波族下的所有函数： ['sym2', 'sym3', 'sym4', 'sym5', 'sym6', 'sym7', 'sym8', 'sym9', 'sym10', 'sym11', 'sym12', 'sym13', 'sym14', 'sym15', 'sym16', 'sym17', 'sym18', 'sym19', 'sym20']

# %%
res_4 = pywt.wavedec(np.array(pa.close),wavelet='sym8',mode='symmetric',level=4)

# %%
res_4_df = pd.DataFrame([res_4[0],res_4[1],res_4[2],res_4[3],res_4[4]],index=['main','high1','high2','high3','high4']).T
res_4_df.head(5)
# Out:
#         main         high1     high2     high3         high4
# 0  30.999909  8.376956e-06  0.000030  0.000057  1.880664e-05
# 1  30.999923  2.828383e-05  0.000041 -0.000024 -2.237603e-05
# 2  30.999917 -8.165713e-08 -0.000037 -0.000004 -8.577214e-06
# 3  30.999910  2.174088e-06 -0.000028  0.000055  5.692795e-06
# 4  30.999918 -5.765375e-06  0.000053 -0.000082 -4.748474e-07

# %%
fig = plt.figure(figsize=(14,7))      #设置图形大小
for j in [1,2,3,4]:
    plt.subplot(2,2,j)
    plt.plot(range(len(res_4[j])),res_4[j])
    plt.title('detail'+str(j))

# %% [markdown]
# jump detection

# %%
print(len(pa.close))
for i in range(5):
    print(f'{i} layer\'s length: {len(res_4[i])}')
# Out:
# 700
# 0 layer's length: 57
# 1 layer's length: 57
# 2 layer's length: 100
# 3 layer's length: 186
# 4 layer's length: 357

# %% [markdown]
# $$D_n = d \sqrt{2\ log\  n},where\ d is\ the\ median\ of\ \{|Y_{j_n,k},k=1,...,2^{j_n}|\}\ divided\ by\ 0.6745$$

# %%
Dn=[]
for i in range(1,5):
    n=len(pa.close)
    d = np.median(np.abs(res_4[i]))
    Di = d * np.sqrt(2*np.log(n))
    Di /= 0.6745
    Dn.append(Di)
    
Dn
# Out:
# [0.0001149125636319751,
#  8.063337059044409e-05,
#  7.222990177670518e-05,
#  5.3156269843983134e-05]

# %%
fig = plt.figure(figsize=(14,7))      #设置图形大小
for j in [1,2,3,4]:
    plt.subplot(2,2,j)
    plt.plot(range(len(res_4[j])),res_4[j])
    plt.title('detail'+str(j))
    plt.hlines(y=Dn[j-1],xmin=0,xmax=len(res_4[j]),color='green')
    plt.hlines(y=-Dn[j-1],xmin=0,xmax=len(res_4[j]),color='green')

# %%
jump_point = []
wholelength = len(pa.close)
for i in range(1,5):
    length = len(res_4[i])
    index= (np.round(np.array(np.where(abs(res_4[i])>abs(Dn[i-1])))*wholelength/length)).astype(int).tolist()[0]
    jump_point+=index

jump_point.sort()
jump_point = jump_point[1:]
jump_point
# Out:
# [33, 147, 168, 403, 416, 418, 427, 453, 459, 461, 490, 602, 669]

# %%
markindex=np.array([False]*wholelength)
markindex[jump_point]=True

# %%
plt.figure(figsize=(15, 6))
plt.plot(pa.close, label='close',c='b')
plt.plot(pa.close, 'o', label='outliers',markevery=markindex,c='r')

# %% [markdown]
# remove jump

# %%
delta = np.int(wholelength * 1/np.sqrt(wholelength))

# %%
l=0
for point in jump_point:
    right = point+delta if point+delta<wholelength else wholelength-1
    left = point-delta if point-delta>-1 else 0
    print(left)
    yp = pa.close[point:right].mean()
    yn = pa.close[left:point].mean()
    li=yp-yn
    l+=li
    
l
# Out:
# 7
# 121
# 142
# 377
# 390
# 392
# 401
# 427
# 433
# 435
# 464
# 576
# 643
# -0.00010230769230190617

# %% [markdown]
# 降噪处理
#
# 1. 按绝对值排序signal
# 2. 计算每个值的风险：
#     $$Risk_j = (N-2*j+ (N-j)*(signal_{N-j}) + \sum_{i=0}^j(signal_i))/N$$

# %%
def threshold_cal(signal):
    '''regrsure 无偏风险估计阈值'''
    signal = abs(signal)
    signal.sort()
    signal = signal**2
    list_risk = [];N=len(signal)
    for j in range(N):
        if j==0:
            risk_j = 1+signal[N-1]
        else:
            risk_j = (N-2*j+ (N-j)*(signal[N-j]) + sum(signal[:j]))/N
        list_risk.append(risk_j)
    k=np.array(list_risk).argmin()
    threshold = np.sqrt(signal[k])
    return threshold

# %%
for j in [3,4]:     #对于高频的信号进行阈值处理
    signal = np.array(res_4[j])
    threshold = threshold_cal(signal)       #固定阈值方法 np.sqrt(2*np.log(len(signal)))
    res_4[j] = pywt.threshold(signal, threshold, 'soft')
    
rec_4 = pywt.waverec(res_4, 'sym8')

# %%
pa['wavelet_close'] = rec_4
fig = plt.figure(figsize=(12,8))      #设置图形大小
plt.subplot(2,1,1)
plt.plot(pa.index,pa.close,color='blue')
plt.title('pa.close')
plt.subplot(2,1,2)
plt.plot(pa.index,pa.wavelet_close,color='red')
plt.title('pa.close after wavelet')
plt.show()

# %%
res_5 = pywt.wavedec(np.array(pa.close),wavelet='sym8',mode='symmetric',level=5)
Dn=[]
for i in range(1,6):
    n=len(pa.close)
    d = np.median(np.abs(res_5[i]))
    Di = d * np.sqrt(2*np.log(n))
    Di /= 0.6745
    Dn.append(Di)
    
Dn
# Out:
# [0.00016923715085022378,
#  0.0001149125636319751,
#  8.063337059044409e-05,
#  7.222990177670518e-05,
#  5.3156269843983134e-05]

# %%
fig = plt.figure(figsize=(14,7))      #设置图形大小
for j in [2,3,4,5]:
    plt.subplot(2,2,j-1)
    plt.plot(range(len(res_5[j])),res_5[j])
    plt.title('detail'+str(j))
    plt.hlines(y=Dn[j-1],xmin=0,xmax=len(res_5[j]),color='green')
    plt.hlines(y=-Dn[j-1],xmin=0,xmax=len(res_5[j]),color='green')
